# %% [markdown]
# # PlateVision — Notebook 03 : Module B — Clustering non supervisé
#
# **Objectif :** K-Means sur embeddings CNN, visualisation PCA/t-SNE, interprétation clusters MINT/DGI
# **Responsable :** Étudiant 3

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# ## 1. Chargement et normalisation des embeddings

# %%
from modules.module_b.clustering import load_embeddings, normalize_embeddings
# embeddings = load_embeddings(Path('../models/embeddings.npy'))
# embeddings_norm, scaler = normalize_embeddings(embeddings)
# print(f'Embeddings: {embeddings.shape}')

# %% [markdown]
# ## 2. Méthode du coude — choix optimal de K

# %%
from modules.module_b.clustering import find_optimal_k
from modules.module_b.visualization import plot_elbow_curve
# inertia, silhouette = find_optimal_k(embeddings_norm, k_range=range(2, 15))
# plot_elbow_curve(list(range(2, 15)), inertia, Path('../reports/rapport_technique'))

# %% [markdown]
# ## 3. K-Means et visualisation PCA / t-SNE

# %%
from modules.module_b.clustering import train_kmeans
from modules.module_b.visualization import generate_all_visualizations
# kmeans, labels, metrics = train_kmeans(embeddings_norm, n_clusters=8)
# print(f"Silhouette: {metrics['silhouette_score']:.4f}")
# generate_all_visualizations(embeddings_norm, labels, Path('../reports/rapport_technique'))

# %% [markdown]
# ## 4. Interprétation des clusters MINT/DGI

# %%
from modules.module_b.interpret_clusters import analyze_cluster_texts, build_cluster_summary_table
# Remplacer par les vrais textes OCR issus du Module A2
# plate_texts = ['LT1234A', 'CE5678B', 'CD001A', ...]
# cluster_analysis = analyze_cluster_texts(plate_texts, labels, n_clusters=8)
# df = build_cluster_summary_table(cluster_analysis)
# df
