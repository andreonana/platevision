# %% [markdown]
# # PlateVision — Notebook 02 : Module A — Baseline Naïves Bayes & YOLO+OCR
#
# **Objectif :** Expérimenter les deux approches du Module A et comparer leurs métriques
# **Responsables :** Étudiant 1 (A1) + Étudiant 2 (A2)

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from dotenv import load_dotenv
load_dotenv()
print('Environnement chargé')

# %% [markdown]
# ## A1 — Classifieur Naïves Bayes
#
# ### Extraction des features

# %%
from preprocessing.feature_extraction import extract_features_from_dataset
# X, filenames = extract_features_from_dataset(Path('../data/processed'))
# print(f'Features shape: {X.shape}')

# %% [markdown]
# ### Entraînement et évaluation Naïves Bayes

# %%
from modules.module_a.naive_bayes import run_naive_bayes_pipeline
# metrics = run_naive_bayes_pipeline(Path('../data/processed'), Path('../reports/'))
# print(f"Accuracy : {metrics['accuracy']:.4f}")

# %% [markdown]
# ## A2 — Pipeline YOLO + OCR
#
# ### Test sur quelques images

# %%
# from modules.module_a.yolo_ocr_pipeline import run_yolo_ocr_pipeline
# results = run_yolo_ocr_pipeline(Path('../data/processed'), Path('../reports/'))
# for r in results[:5]:
#     print(f"{r['image']} → '{r['plate_text']}' (conf: {r['confidence']:.2f})")

# %% [markdown]
# ## Comparaison des métriques A1 vs A2
#
# | Métrique | Naïves Bayes (A1) | YOLO+OCR (A2) |
# |----------|------------------|---------------|
# | Accuracy/mAP | ___ | ___ |
# | CER | N/A | ___ |
# | WER | N/A | ___ |
# | Temps inférence | ___ | ___ |
